# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df1 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/PUB/PUB Dataset/task_1.jsonl', lines=True)
df2 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/PUB/PUB Dataset/task_2.jsonl', lines=True)
df3 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/PUB/PUB Dataset/task_3.jsonl', lines=True)
df4 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/PUB/PUB Dataset/task_4.jsonl', lines=True)
df5 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/PUB/PUB Dataset/task_5.jsonl', lines=True)
d
# Out:
# <ipython-input-3-b97688b46d25>:3: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/task_1.jsonl', lines=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b97688b46d25> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df1 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/task_1.jsonl', lines=True)
#       4 df2 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/task_2.jsonl', lines=True)
#       5 df3 = pd.read_json('/content/drive/Othercomputers/My MacBook Air/Documents/IITB-Sem01/CS779 -RnD/task_3.jsonl', lines=True)
#
# ...

# %%
# Task 1:Direct / Indirect Classification
df1.head()[0]

# %%
df1.info()

# %%
# Response Classification : Without Implied Meaning
df2.head()
# Out:
#                                              pretext  \
# 0  Context: X and Y are childhood neighbours who ...
# 1  Context: Y has just moved into a neighbourhood...
# 2  Context: X wants to know what activities Y lik...
# 3  Context: X and Y are colleagues who are leavin...
# 4  Context: Y has just told X that he/she is cons...
#
#                                              options correct answer  id
# 0  [Yes, No, Yes, subject to some conditions, In ...            Yes   0
# 1  [Yes, No, Yes, subject to some conditions, In ...            Yes   1
# 2  [Yes, No, Yes, subject to some conditions, In ...             No   2
# 3  [Yes, No, Yes, subject to some conditions, In ...            Yes   3
# 4  [Yes, No, Yes, subject to some conditions, In ...            Yes   4

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pretext         2506 non-null   object
#  1   options         2506 non-null   object
#  2   correct answer  2506 non-null   object
#  3   id              2506 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 78.4+ KB

# %%
#Response Classification : With Implied Meaning
df3.head()
# Out:
#                                              pretext  \
# 0  Context: X and Y are childhood neighbours who ...
# 1  Context: Y has just moved into a neighbourhood...
# 2  Context: X wants to know what activities Y lik...
# 3  Context: X and Y are colleagues who are leavin...
# 4  Context: Y has just told X that he/she is cons...
#
#                                              options correct answer  id
# 0  [Yes, No, Yes, subject to some conditions, In ...            Yes   0
# 1  [Yes, No, Yes, subject to some conditions, In ...            Yes   1
# 2  [Yes, No, Yes, subject to some conditions, In ...             No   2
# 3  [Yes, No, Yes, subject to some conditions, In ...            Yes   3
# 4  [Yes, No, Yes, subject to some conditions, In ...            Yes   4

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pretext         2506 non-null   object
#  1   options         2506 non-null   object
#  2   correct answer  2506 non-null   object
#  3   id              2506 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 78.4+ KB

# %%
df4.head()
# Out:
#                                              pretext  \
# 0  Speaker_1: did Liam leave the watermelons in t...
# 1  Speaker_1: how many potatoes are in the lounge...
# 2  Speaker_1: are all the strawberries in the sta...
# 3  Speaker_1: did Elizabeth place the tomatoes in...
# 4  Speaker_1: where did Isabella go\nSpeaker_2: s...
#
#                                              options  \
# 0  [Liam put the cherries in the kitchen and then...
# 1  [the pineapples are not in the TV_room, the pi...
# 2  [four of the persimmons are in the bedroom, I ...
# 3  [I left the green peppers in the workshop and ...
# 4  [the oranges are not in the workshop, I am not...
#
#                                       correct answer  id
# 0  Liam put the cherries in the kitchen and then ...   0
# 1             I am not sure where the pineapples are   1
# 2          some of the persimmons are in the bedroom   2
# 3  I left the green peppers in the workshop and t...   3
# ...
